# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./titanic_data.csv')
data.head(10)
print(data.shape)
# Out:
# (891, 12)

# %%
train = data.iloc[0:600 , :]
test = data.iloc[600: , :]

print(train.shape)
print(test.shape)
# Out:
# (600, 12)
# (291, 12)

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
test.head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 600          601         1       2
# 601          602         0       3
# 602          603         0       1
# 603          604         0       3
# 604          605         1       1
# 605          606         0       3
# 606          607         0       3
# 607          608         1       1
# 608          609         1       2
# 609          610         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 600  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...  female  24.0      2
# 601                               Slabenoff, Mr. Petco    male   NaN      0
# 602                          Harrington, Mr. Charles H    male   NaN      0
# 603                          Torber, Mr. Ernst William    male  44.0      0
# 604                    Homer, Mr. Harry ("Mr E Haven")    male  35.0      0
# 605                      Lindell, Mr. Edvard Bengtsson    male  36.0      1
# ...

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            126
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          463
# Embarked         1
# dtype: int64

# %%
train = train.drop(columns=["Cabin"])

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
train["Embarked"] = train["Embarked"].fillna("S")

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            126
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 595          596         0       3
# 596          597         1       2
# 597          598         0       3
# 598          599         0       3
# 599          600         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print("No. of Males survived in the ship : " ,train["Survived"][train["Sex"]=="male"].value_counts(normalize=True)[1]*100)
print("No. of Females survived in the ship : " ,train["Survived"][train["Sex"]=="female"].value_counts(normalize=True)[1]*100)
# Out:
# No. of Males survived in the ship :  18.30238726790451
# No. of Females survived in the ship :  74.88789237668162

# %%
sns.barplot(x = "Sex" , y = "Survived" , data = train , palette='viridis').set_ylabel("Survival Probability")
# Out:
# Text(0, 0.5, 'Survival Probability')

# %%
sns.barplot(x = "Pclass" , y = "Survived" , data = train  ,palette='viridis').set_ylabel("Survival Probability")
# Out:
# Text(0, 0.5, 'Survival Probability')

# %%
sns.barplot(x = "Pclass" , y = "Survived" , data = train, hue="Sex"  ,palette='viridis').set_ylabel("Survival Probability")
# Out:
# Text(0, 0.5, 'Survival Probability')

# %%
sns.barplot(x = "Embarked" , y= "Survived" , data = train , palette='viridis').set_ylabel("Embarked Regions")
# Out:
# Text(0, 0.5, 'Embarked Regions')

# %%
sns.barplot(x = "Embarked" , y= "Survived" ,hue="Sex" , data = train , palette='viridis').set_ylabel("Embarked Regions")
# Out:
# Text(0, 0.5, 'Embarked Regions')

# %%
sibsp_counts=train["SibSp"].value_counts().reset_index()
sibsp_counts.columns = ['SibSp', 'Count']

# Create the bar plot
sns.barplot(x="SibSp" ,y="Count" , data=sibsp_counts, palette='viridis')

# Rotate x-axis labels
plt.xticks(rotation=0)

# Set the labels and title
plt.xlabel("Number of Siblings/Spouses")
plt.ylabel("Count")
plt.title("Count of Siblings/Spouses on Titanic")



# Show the plot
plt.show()

# %% [markdown]
# ### ``` Its clear from above plot that ones who have least sibblings have survived the most and one who have more sibblings have least survived ```

# %%
# # Calculate age group counts and survival counts
# cond1 = train[train["Age"]<10]["Age"].count()
# cond2 = train[(train["Age"]>=10) & (train["Age"]<25)]["Age"].count()
# cond3 = train[(train["Age"]>=25) & (train["Age"]<40)]["Age"].count()
# cond5 = train[(train["Age"]>=40) & (train["Age"]<55)]["Age"].count()
# cond6 = train[(train["Age"]>=55) & (train["Age"]<70)]["Age"].count()
# cond7 = train[train["Age"]>=70]["Age"].count()

# counts = [cond1, cond2, cond3, cond5, cond6, cond7]

# cond1_survived = train[(train["Age"]<10) & (train["Survived"]==1)]["Age"].count()
# cond2_survived = train[(train["Age"]>=10) & (train["Age"]<25) & (train["Survived"]==1)]["Age"].count()
# cond3_survived = train[(train["Age"]>=25) & (train["Age"]<40) & (train["Survived"]==1)]["Age"].count()
# cond5_survived = train[(train["Age"]>=40) & (train["Age"]<55) & (train["Survived"]==1)]["Age"].count()
# cond6_survived = train[(train["Age"]>=55) & (train["Age"]<70) & (train["Survived"]==1)]["Age"].count()
# cond7_survived = train[(train["Age"]>=70) & (train["Survived"]==1)]["Age"].count()

# survived_counts = [cond1_survived, cond2_survived, cond3_survived, cond5_survived, cond6_survived, cond7_survived]

# Age_grp = ["Age<10", "10<Age<25", "25<Age<40", "40<Age<55", "55<Age<70", "70<Age"]

# # Create DataFrame
# df = pd.DataFrame({"Age": Age_grp, "Count": counts, "Survived": survived_counts})

# # Melt the DataFrame for seaborn
# # df_melted = pd.melt(df, id_vars='Age', value_vars=['Count', 'Survived'], var_name='Type', value_name='Count')

# # Plot using seaborn
# sns.barplot(x="Age", y="Count", data=df, palette='viridis')

# # Add labels and title
# plt.xlabel("Age")
# plt.ylabel("Count")
# plt.title("Count of Age Groups on Titanic Ship")
# plt.show()

# %% [markdown]
# ### `Making Buckets of age to find the survival `

# %%
train.Age = train.Age.fillna(-0.5)
test.Age = test.Age.fillna(-0.5)

bins = [-1,0,5,12,18,24,35,60 , np.inf]
label = ["Unknown" , "Baby" , "Child" , "Teenager" , "Student" , "Young_Adult" , "Adult" , "Senior"]

train["Age_grp"] = pd.cut(train["Age"] , bins , labels=label)
test["Age_grp"] = pd.cut(test["Age"] , bins , labels=label)

sns.barplot(x = "Age_grp" , y= "Survived"  , data = train , palette='viridis')
plt.show()

# %% [markdown]
# ### `So we can clearly observe that babies has the highest chances of survival since every family want their babies to live`

# %%
# q = sns.catplot('Pclass' , col='Embarked' , data=data , kind='count' , palette='viridis')
q = sns.catplot(x='Pclass', col='Embarked', data=train, kind='count', palette='pastel', height=4)
q.despine(left=True)
q.set_ylabels('Count')

# %%
# q = sns.catplot('Pclass' , col='Embarked' , data=data , kind='count' , palette='viridis')
q = sns.catplot(x='Sex', col='Embarked', data=train, kind='count', palette='autumn', height=4)
q.despine(left=True)
q.set_ylabels('Count')

# %%
# q = sns.catplot('Pclass' , col='Embarked' , data=data , kind='count' , palette='viridis')
q = sns.catplot(x='Survived', col='Embarked', data=train, kind='count', palette='pastel', height=4)
q.despine(left=True)
q.set_ylabels('Count')

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked', 'Age_grp'],
#       dtype='object')

# %%
train  = train.drop(["Ticket" , "Fare" ] , axis=1)

# %%
test  = test.drop(["Ticket" , "Fare" ] , axis=1)

# %% [markdown]
# ## `Feature Engineering`

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  -0.5      0
# ...

# %%
Sx = {"male":1 , "female" :0}
train["Sex"] = train["Sex"].map(Sx)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#   Embarked      Age_grp
# 0        S      Student
# 1        C        Adult
# 2        S  Young_Adult
# 3        S  Young_Adult
# 4        S  Young_Adult

# %% [markdown]
# [A-Za-z] stands for upper or lowercase letters. + means 1 or more consecutive. Together, [A-Za-z]+ means 1 or more consecutive letters. The () is the capture group that you want to return and by default, str.extract() will return the first capture group. As an example of how to return last name, you could do monte.str.extract('\s+([A-Za-z]+)') where \s+ is one or more consecutive spaces. Notice, it is outside the capture group, but given the space, that means it must capture the last name since there is no space before the first name. –

# %%
combine = [train,test]

for dataset in combine:
    dataset['title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(train['title'], train['Sex'])
# Out:
# Sex       0    1
# title
# Don       0    1
# Dr        0    3
# Lady      1    0
# Major     0    2
# Master    0   27
# Miss    135    0
# Mme       1    0
# Mr        0  340
# Mrs      85    0
# Ms        1    0
# Rev       0    3
# Sir       0    1

# %%
for dataset in combine:
    dataset['title'].replace(['Don', 'Rev', 'Dr', 'Major', 'Capt', 'Jonkheer', 'Col', 'Mlle', 'Countess', 'Sir', 'Lady', 'Dona'], 'Rare', inplace=True)
    dataset['title'].replace(['Mme', 'Ms', 'Mrs'], 'Mrs', inplace=True)
    dataset['title'].replace(['Mlle', 'Miss'], 'Miss', inplace=True)
    dataset['title'].replace(['Mr'], 'Mr', inplace=True)


train[['title', 'Survived']].groupby(['title'], as_index=False).mean()
# Out:
#     title  Survived
# 0  Master  0.518519
# 1    Miss  0.703704
# 2      Mr  0.155882
# 3     Mrs  0.816092
# 4    Rare  0.272727

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5} 

for dataset in combine:
    dataset['title'] = dataset['title'].map(title_mapping)
    dataset['title'] = dataset['title'].fillna(0)

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#   Embarked      Age_grp  title
# 0        S      Student      1
# 1        C        Adult      3
# 2        S  Young_Adult      2
# 3        S  Young_Adult      3
# 4        S  Young_Adult      1

# %%
print(train["Age_grp"][0])
print(test["Age_grp"][600+0])
print(test["title"])
# Out:
# Student
# Student
# 600    3
# 601    1
# 602    1
# 603    1
# 604    1
#       ..
# 886    5
# 887    2
# 888    2
# 889    1
# 890    1
# Name: title, Length: 291, dtype: int64

# %%
mr_age = train[train["title"] == 1]["Age_grp"].mode()
miss_age = train[train["title"] == 2]["Age_grp"].mode()
mrs_age = train[train["title"] == 3]["Age_grp"].mode()
master_age = train[train["title"] == 4]["Age_grp"].mode()
royal_age = train[train["title"]==5]["Age_grp"].mode()
rare_age = train[train["title"] == 6]["Age_grp"].mode()

age_title_mapping = {1:"Young_Adult" , 2:"Student", 3:"Adult", 4:"Baby", 5:"Adult" , 6:"Adult"}


for i in range(len(train['Age_grp'])):
    if train['Age_grp'][i]=='Unknown':
        train['Age_grp'][i] == age_title_mapping[train["title"][i]]

for i in range(len(test['Age_grp'])):
    if test['Age_grp'][600+i]=='Unknown':
        test['Age_grp'][600+i] == age_title_mapping[test["title"][600+i]]

# %%
train.Age_grp.unique()
# Out:
# ['Student', 'Adult', 'Young_Adult', 'Unknown', 'Baby', 'Teenager', 'Child', 'Senior']
# Categories (8, object): ['Unknown' < 'Baby' < 'Child' < 'Teenager' < 'Student' < 'Young_Adult' < 'Adult' < 'Senior']

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#   Embarked      Age_grp  title
# 0        S      Student      1
# 1        C        Adult      3
# 2        S  Young_Adult      2
# 3        S  Young_Adult      3
# 4        S  Young_Adult      1

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

transform = ["Embarked" , "Age_grp" , "Sex" ]

for i in transform:
    train[i] = le.fit_transform(train[i])

# %%
for i in transform:
    test[i] = le.fit_transform(test[i])

# %% [markdown]
# ## `Machine learning Model`

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#    Embarked  Age_grp  title
# 0         2        4      1
# 1         0        0      3
# 2         2        7      2
# 3         2        7      3
# 4         2        7      1

# %%
x_train = train.drop(["Name" ,"Survived" , "PassengerId"] , axis=1)
y_train = train["Survived"]

x_test = test.drop(["PassengerId" , "Cabin" , "Name" , "Survived"] , axis=1)

y_test = test["Survived"]

# %%
test.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 600          601         1       2
# 601          602         0       3
# 602          603         0       1
# 603          604         0       3
# 604          605         1       1
#
#                                                   Name  Sex   Age  SibSp  \
# 600  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...    0  24.0      2
# 601                               Slabenoff, Mr. Petco    1  -0.5      0
# 602                          Harrington, Mr. Charles H    1  -0.5      0
# 603                          Torber, Mr. Ernst William    1  44.0      0
# 604                    Homer, Mr. Harry ("Mr E Haven")    1  35.0      0
#
#      Parch Cabin  Embarked  Age_grp  title
# 600      1   NaN         2        4      3
# 601      0   NaN         2        6      1
# 602      0   NaN         2        6      1
# 603      0   NaN         2        0      1
# 604      0   NaN         0        7      1

# %%
x_test.dtypes
# Out:
# Pclass        int64
# Sex           int32
# Age         float64
# SibSp         int64
# Parch         int64
# Embarked      int32
# Age_grp       int32
# title         int64
# dtype: object

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

logreg = LogisticRegression()
svc_classifier = SVC()
dt_classifier = DecisionTreeClassifier()
knn_classifier = KNeighborsClassifier(5)
rf_classifier = RandomForestClassifier(n_estimators=1000, criterion = 'entropy', random_state = 0 )

# %%
logreg.fit(x_train, y_train)
svc_classifier.fit(x_train, y_train)
dt_classifier.fit(x_train, y_train)
knn_classifier.fit(x_train, y_train)
rf_classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=1000, random_state=0)

# %%
logreg_ypred = logreg.predict(x_test)
svc_classifier_ypred = svc_classifier.predict(x_test)
dt_classifier_ypred = dt_classifier.predict(x_test)
knn_classifier_ypred = knn_classifier.predict(x_test)
rf_classifier_ypred = rf_classifier.predict(x_test)

# %%
# finding accuracy
from sklearn.metrics import accuracy_score

logreg_acc = accuracy_score(y_test, logreg_ypred)
svc_classifier_acc = accuracy_score(y_test, svc_classifier_ypred)
dt_classifier_acc = accuracy_score(y_test, dt_classifier_ypred)
knn_classifier_acc = accuracy_score(y_test, knn_classifier_ypred)
rf_classifier_acc = accuracy_score(y_test, rf_classifier_ypred)

# %% [markdown]
# ### `Most Accurate algorithm is K-NN Classifier`

# %%
print ("Logistic Regression : ", round(logreg_acc*100, 2) , '%')
print ("Support Vector      : ", round(svc_classifier_acc*100, 2) , '%')
print ("Decision Tree       : ", round(dt_classifier_acc*100, 2) , '%')
print ("K-NN Classifier     : ", round(knn_classifier_acc*100, 2) , '%')
print ("Random Forest       : ", round(rf_classifier_acc*100, 2) , '%')
# Out:
# Logistic Regression :  79.38 %
# Support Vector      :  65.98 %
# Decision Tree       :  76.63 %
# K-NN Classifier     :  82.47 %
# Random Forest       :  78.69 %

# %%
ids = test["PassengerId"]

output = pd.DataFrame({"PassengerId" : ids , "Survived" : knn_classifier_ypred})
output.to_csv("submission.csv" , index=False)
